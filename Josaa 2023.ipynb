# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
import pandas as pd

# %%
df_round1 = pd.read_csv("archive\Round_1.csv")

# %%
df_round1.head()
# Out:
#                                      Institute  \
# 0  Indian Institute  of Technology Bhubaneswar
# 1  Indian Institute  of Technology Bhubaneswar
# 2  Indian Institute  of Technology Bhubaneswar
# 3  Indian Institute  of Technology Bhubaneswar
# 4  Indian Institute  of Technology Bhubaneswar
#
#                                Academic Program Name Quota Seat Type  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1  Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2  Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3  Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 4  Civil Engineering (4 Years, Bachelor of Techno...    AI   OBC-NCL
#
#                                   Gender Opening Rank Closing Rank
# 0                         Gender-Neutral         9462        12911
# 1  Female-only (including Supernumerary)        16218        19272
# 2                         Gender-Neutral         1852         1977
# 3  Female-only (including Supernumerary)         3056         3056
# 4                         Gender-Neutral         4014         4642

# %%
df_round1= df_round1[~df_round1['Seat Type'].str.contains('PwD')]

# %%
df_round1 = df_round1.reset_index(drop=True)

# %%
df_round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9485 entries, 0 to 9484
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              9485 non-null   object
#  1   Academic Program Name  9485 non-null   object
#  2   Quota                  9485 non-null   object
#  3   Seat Type              9485 non-null   object
#  4   Gender                 9485 non-null   object
#  5   Opening Rank           9485 non-null   object
#  6   Closing Rank           9485 non-null   object
# dtypes: object(7)
# memory usage: 518.8+ KB

# %%
x = df_round1["Academic Program Name"].nunique()
print(f"There are total of {x} academic programs offered through Josaa.")
# Out:
# There are total of 211 academic programs offered through Josaa.

# %%
df_round1['Opening Rank'] = df_round1['Opening Rank'].str.replace(r'P', '', regex=True)

# %%
df_round1['Opening Rank'] = pd.to_numeric(df_round1['Opening Rank'])

# %%
df_round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9485 entries, 0 to 9484
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              9485 non-null   object
#  1   Academic Program Name  9485 non-null   object
#  2   Quota                  9485 non-null   object
#  3   Seat Type              9485 non-null   object
#  4   Gender                 9485 non-null   object
#  5   Opening Rank           9485 non-null   int64
#  6   Closing Rank           9485 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 518.8+ KB

# %%
df_round1['Closing Rank'] = df_round1['Closing Rank'].str.replace(r'P', '', regex=True)

# %%
df_round1['Closing Rank'] = pd.to_numeric(df_round1['Closing Rank'])

# %%
df_round1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9485 entries, 0 to 9484
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              9485 non-null   object
#  1   Academic Program Name  9485 non-null   object
#  2   Quota                  9485 non-null   object
#  3   Seat Type              9485 non-null   object
#  4   Gender                 9485 non-null   object
#  5   Opening Rank           9485 non-null   int64
#  6   Closing Rank           9485 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 518.8+ KB

# %%
sorted_opening = df_round1.sort_values(by='Opening Rank')

# %%
sorted_opening
# Out:
#                                          Institute  \
# 186         Indian Institute  of Technology Bombay
# 178         Indian Institute  of Technology Bombay
# 8949  School of Planning & Architecture, New Delhi
# 184         Indian Institute  of Technology Bombay
# 3821      National Institute of Technology Calicut
# ...                                            ...
# 6063     National Institute of Technology, Mizoram
# 6033     National Institute of Technology, Mizoram
# 6045     National Institute of Technology, Mizoram
# 6046     National Institute of Technology, Mizoram
# 6064     National Institute of Technology, Mizoram
#
#                                   Academic Program Name Quota Seat Type  \
# 186   Computer Science and Engineering (4 Years, Bac...    AI        ST
# 178   Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 8949  Architecture  (5 Years, Bachelor of Architecture)    AI        ST
# 184   Computer Science and Engineering (4 Years, Bac...    AI        SC
# 3821  Architecture  (5 Years, Bachelor of Architecture)    HS        SC
# ...                                                 ...   ...       ...
# 6063  Mechanical Engineering (4 Years, Bachelor of T...    HS      OPEN
# 6033  Electrical Engineering (4 Years, Bachelor of T...    HS      OPEN
# 6045  Electronics and Communication Engineering (4 Y...    HS      OPEN
# 6046  Electronics and Communication Engineering (4 Y...    HS      OPEN
# 6064  Mechanical Engineering (4 Years, Bachelor of T...    HS      OPEN
#
#                                      Gender  Opening Rank  Closing Rank
# 186                          Gender-Neutral             1            10
# 178                          Gender-Neutral             1            66
# 8949                         Gender-Neutral             1            23
# 184                          Gender-Neutral             2            25
# 3821                         Gender-Neutral             5           145
# ...                                     ...           ...           ...
# 6063                         Gender-Neutral        556736        742762
# 6033  Female-only (including Supernumerary)        560594        614925
# 6045                         Gender-Neutral        573968        684517
# 6046  Female-only (including Supernumerary)        589620        755659
# 6064  Female-only (including Supernumerary)        659805        758764
#
# [9485 rows x 7 columns]

# %%
nit_trichy = df_round1[df_round1["Institute"] == "National Institute of Technology, Tiruchirappalli"]

# %%
nit_trichy.nunique()
# Out:
# Institute                  1
# Academic Program Name     10
# Quota                      2
# Seat Type                  5
# Gender                     2
# Opening Rank             192
# Closing Rank             193
# dtype: int64

# %%
sorted_NIT_TRICHY = nit_trichy.sort_values(by='Opening Rank')

# %%
sorted_NIT_TRICHY
# Out:
#                                               Institute  \
# 6717  National Institute of Technology, Tiruchirappalli
# 6726  National Institute of Technology, Tiruchirappalli
# 6727  National Institute of Technology, Tiruchirappalli
# 6725  National Institute of Technology, Tiruchirappalli
# 6783  National Institute of Technology, Tiruchirappalli
# ...                                                 ...
# 6868  National Institute of Technology, Tiruchirappalli
# 6876  National Institute of Technology, Tiruchirappalli
# 6748  National Institute of Technology, Tiruchirappalli
# 6729  National Institute of Technology, Tiruchirappalli
# 6885  National Institute of Technology, Tiruchirappalli
#
#                                   Academic Program Name Quota Seat Type  \
# 6717  Architecture  (5 Years, Bachelor of Architecture)    HS        SC
# 6726  Architecture  (5 Years, Bachelor of Architecture)    OS        ST
# 6727  Architecture  (5 Years, Bachelor of Architecture)    OS        ST
# 6725  Architecture  (5 Years, Bachelor of Architecture)    OS        SC
# 6783  Computer Science and Engineering (4 Years, Bac...    OS        SC
# ...                                                 ...   ...       ...
# 6868  Metallurgical and Materials Engineering (4 Yea...    HS       EWS
# 6876  Metallurgical and Materials Engineering (4 Yea...    OS      OPEN
# 6748  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6729  Chemical Engineering (4 Years, Bachelor of Tec...    HS      OPEN
# 6885  Production Engineering (4 Years, Bachelor of T...    HS      OPEN
#
#                                      Gender  Opening Rank  Closing Rank
# 6717  Female-only (including Supernumerary)            13            13
# 6726                         Gender-Neutral            21            21
# 6727  Female-only (including Supernumerary)            26            26
# 6725  Female-only (including Supernumerary)            29            29
# 6783                         Gender-Neutral            39           268
# ...                                     ...           ...           ...
# 6868  Female-only (including Supernumerary)         22517         22517
# 6876  Female-only (including Supernumerary)         22701         24755
# 6748  Female-only (including Supernumerary)         25454         37742
# 6729  Female-only (including Supernumerary)         26164         29202
# 6885  Female-only (including Supernumerary)         26747         33458
#
# [194 rows x 7 columns]

# %%
open_NIT_trichy = sorted_NIT_TRICHY[sorted_NIT_TRICHY['Seat Type'] == "OPEN"]

# %%
open_NIT_trichy
# Out:
#                                               Institute  \
# 6711  National Institute of Technology, Tiruchirappalli
# 6777  National Institute of Technology, Tiruchirappalli
# 6710  National Institute of Technology, Tiruchirappalli
# 6719  National Institute of Technology, Tiruchirappalli
# 6720  National Institute of Technology, Tiruchirappalli
# 6767  National Institute of Technology, Tiruchirappalli
# 6778  National Institute of Technology, Tiruchirappalli
# 6816  National Institute of Technology, Tiruchirappalli
# 6768  National Institute of Technology, Tiruchirappalli
# 6797  National Institute of Technology, Tiruchirappalli
# 6845  National Institute of Technology, Tiruchirappalli
# 6757  National Institute of Technology, Tiruchirappalli
# 6855  National Institute of Technology, Tiruchirappalli
# 6807  National Institute of Technology, Tiruchirappalli
# 6835  National Institute of Technology, Tiruchirappalli
# 6817  National Institute of Technology, Tiruchirappalli
# 6787  National Institute of Technology, Tiruchirappalli
# 6739  National Institute of Technology, Tiruchirappalli
# 6826  National Institute of Technology, Tiruchirappalli
# 6808  National Institute of Technology, Tiruchirappalli
# 6798  National Institute of Technology, Tiruchirappalli
# 6738  National Institute of Technology, Tiruchirappalli
# 6856  National Institute of Technology, Tiruchirappalli
# 6836  National Institute of Technology, Tiruchirappalli
# 6788  National Institute of Technology, Tiruchirappalli
# 6728  National Institute of Technology, Tiruchirappalli
# 6875  National Institute of Technology, Tiruchirappalli
# 6894  National Institute of Technology, Tiruchirappalli
# 6846  National Institute of Technology, Tiruchirappalli
# 6827  National Institute of Technology, Tiruchirappalli
# 6747  National Institute of Technology, Tiruchirappalli
# 6865  National Institute of Technology, Tiruchirappalli
# 6884  National Institute of Technology, Tiruchirappalli
# 6895  National Institute of Technology, Tiruchirappalli
# 6866  National Institute of Technology, Tiruchirappalli
# 6758  National Institute of Technology, Tiruchirappalli
# 6876  National Institute of Technology, Tiruchirappalli
# 6748  National Institute of Technology, Tiruchirappalli
# 6729  National Institute of Technology, Tiruchirappalli
# 6885  National Institute of Technology, Tiruchirappalli
#
#                                   Academic Program Name Quota Seat Type  \
# 6711  Architecture  (5 Years, Bachelor of Architecture)    HS      OPEN
# 6777  Computer Science and Engineering (4 Years, Bac...    OS      OPEN
# 6710  Architecture  (5 Years, Bachelor of Architecture)    HS      OPEN
# 6719  Architecture  (5 Years, Bachelor of Architecture)    OS      OPEN
# 6720  Architecture  (5 Years, Bachelor of Architecture)    OS      OPEN
# 6767  Computer Science and Engineering (4 Years, Bac...    HS      OPEN
# 6778  Computer Science and Engineering (4 Years, Bac...    OS      OPEN
# 6816  Electronics and Communication Engineering (4 Y...    OS      OPEN
# 6768  Computer Science and Engineering (4 Years, Bac...    HS      OPEN
# 6797  Electrical and Electronics Engineering (4 Year...    OS      OPEN
# 6845  Mechanical Engineering (4 Years, Bachelor of T...    HS      OPEN
# 6757  Civil Engineering (4 Years, Bachelor of Techno...    OS      OPEN
# 6855  Mechanical Engineering (4 Years, Bachelor of T...    OS      OPEN
# 6807  Electronics and Communication Engineering (4 Y...    HS      OPEN
# 6835  Instrumentation and Control Engineering (4 Yea...    OS      OPEN
# 6817  Electronics and Communication Engineering (4 Y...    OS      OPEN
# 6787  Electrical and Electronics Engineering (4 Year...    HS      OPEN
# 6739  Chemical Engineering (4 Years, Bachelor of Tec...    OS      OPEN
# 6826  Instrumentation and Control Engineering (4 Yea...    HS      OPEN
# 6808  Electronics and Communication Engineering (4 Y...    HS      OPEN
# 6798  Electrical and Electronics Engineering (4 Year...    OS      OPEN
# 6738  Chemical Engineering (4 Years, Bachelor of Tec...    OS      OPEN
# 6856  Mechanical Engineering (4 Years, Bachelor of T...    OS      OPEN
# 6836  Instrumentation and Control Engineering (4 Yea...    OS      OPEN
# 6788  Electrical and Electronics Engineering (4 Year...    HS      OPEN
# 6728  Chemical Engineering (4 Years, Bachelor of Tec...    HS      OPEN
# 6875  Metallurgical and Materials Engineering (4 Yea...    OS      OPEN
# 6894  Production Engineering (4 Years, Bachelor of T...    OS      OPEN
# 6846  Mechanical Engineering (4 Years, Bachelor of T...    HS      OPEN
# 6827  Instrumentation and Control Engineering (4 Yea...    HS      OPEN
# 6747  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6865  Metallurgical and Materials Engineering (4 Yea...    HS      OPEN
# 6884  Production Engineering (4 Years, Bachelor of T...    HS      OPEN
# 6895  Production Engineering (4 Years, Bachelor of T...    OS      OPEN
# 6866  Metallurgical and Materials Engineering (4 Yea...    HS      OPEN
# 6758  Civil Engineering (4 Years, Bachelor of Techno...    OS      OPEN
# 6876  Metallurgical and Materials Engineering (4 Yea...    OS      OPEN
# 6748  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6729  Chemical Engineering (4 Years, Bachelor of Tec...    HS      OPEN
# 6885  Production Engineering (4 Years, Bachelor of T...    HS      OPEN
#
#                                      Gender  Opening Rank  Closing Rank
# 6711  Female-only (including Supernumerary)            53            94
# 6777                         Gender-Neutral            86          1147
# 6710                         Gender-Neutral           100           358
# 6719                         Gender-Neutral           118           256
# 6720  Female-only (including Supernumerary)           190           190
# 6767                         Gender-Neutral           936          4661
# 6778  Female-only (including Supernumerary)          1701          2086
# 6816                         Gender-Neutral          1797          3609
# 6768  Female-only (including Supernumerary)          2903          6687
# 6797                         Gender-Neutral          3618          5422
# 6845                         Gender-Neutral          3744         14644
# 6757                         Gender-Neutral          4010         17159
# 6855                         Gender-Neutral          4026          9241
# 6807                         Gender-Neutral          4341          6871
# 6835                         Gender-Neutral          4688         12463
# 6817  Female-only (including Supernumerary)          4789          6252
# 6787                         Gender-Neutral          6915          9254
# 6739  Female-only (including Supernumerary)          7307         16042
# 6826                         Gender-Neutral          7605         14406
# 6808  Female-only (including Supernumerary)          7666          9954
# 6798  Female-only (including Supernumerary)          7962         10272
# 6738                         Gender-Neutral          8663         13360
# 6856  Female-only (including Supernumerary)         10294         17044
# 6836  Female-only (including Supernumerary)         10652         16852
# 6788  Female-only (including Supernumerary)         11085         12625
# 6728                         Gender-Neutral         12050         19125
# 6875                         Gender-Neutral         13340         19830
# 6894                         Gender-Neutral         13815         22066
# 6846  Female-only (including Supernumerary)         14699         21053
# 6827  Female-only (including Supernumerary)         15583         17885
# 6747                         Gender-Neutral         15611         29390
# 6865                         Gender-Neutral         15808         25825
# 6884                         Gender-Neutral         16710         23939
# 6895  Female-only (including Supernumerary)         21081         28511
# 6866  Female-only (including Supernumerary)         21191         37943
# 6758  Female-only (including Supernumerary)         21245         26190
# 6876  Female-only (including Supernumerary)         22701         24755
# 6748  Female-only (including Supernumerary)         25454         37742
# 6729  Female-only (including Supernumerary)         26164         29202
# 6885  Female-only (including Supernumerary)         26747         33458
